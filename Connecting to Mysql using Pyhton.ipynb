# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('..\Data\iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
CSV1=df[["Id","PetalLengthCm","PetalWidthCm"]]

# %%
CSV1
# Out:
#       Id  PetalLengthCm  PetalWidthCm
# 0      1            1.4           0.2
# 1      2            1.4           0.2
# 2      3            1.3           0.2
# 3      4            1.5           0.2
# 4      5            1.4           0.2
# ..   ...            ...           ...
# 145  146            5.2           2.3
# 146  147            5.0           1.9
# 147  148            5.2           2.0
# 148  149            5.4           2.3
# 149  150            5.1           1.8
#
# [150 rows x 3 columns]

# %%
CSV2=df[["SepalLengthCm","SepalWidthCm"]]

# %%
CSV2
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
CSV3=df.loc[df['Species'].isin(['Iris-versicolor', 'Iris-virginica']),['Id', 'Species'] ]
CSV3
# Out:
#       Id          Species
# 50    51  Iris-versicolor
# 51    52  Iris-versicolor
# 52    53  Iris-versicolor
# 53    54  Iris-versicolor
# 54    55  Iris-versicolor
# ..   ...              ...
# 145  146   Iris-virginica
# 146  147   Iris-virginica
# 147  148   Iris-virginica
# 148  149   Iris-virginica
# 149  150   Iris-virginica
#
# [100 rows x 2 columns]

# %%
CSV4=df.loc[df['Species'].isin(['Iris-setosa']),['Id','PetalLengthCm','PetalWidthCm', 'Species'] ]
CSV4
# Out:
#     Id  PetalLengthCm  PetalWidthCm      Species
# 0    1            1.4           0.2  Iris-setosa
# 1    2            1.4           0.2  Iris-setosa
# 2    3            1.3           0.2  Iris-setosa
# 3    4            1.5           0.2  Iris-setosa
# 4    5            1.4           0.2  Iris-setosa
# 5    6            1.7           0.4  Iris-setosa
# 6    7            1.4           0.3  Iris-setosa
# 7    8            1.5           0.2  Iris-setosa
# 8    9            1.4           0.2  Iris-setosa
# 9   10            1.5           0.1  Iris-setosa
# 10  11            1.5           0.2  Iris-setosa
# 11  12            1.6           0.2  Iris-setosa
# 12  13            1.4           0.1  Iris-setosa
# 13  14            1.1           0.1  Iris-setosa
# 14  15            1.2           0.2  Iris-setosa
# 15  16            1.5           0.4  Iris-setosa
# 16  17            1.3           0.4  Iris-setosa
# 17  18            1.4           0.3  Iris-setosa
# ...

# %%
CSV1.to_csv('data1.csv', index=False)

# %%
CSV2.to_csv('data2.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_948\3983895835.py in <module>
# ----> 1 CSV2.to_csv('data2.csv', index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...

# %%
CSV3.to_csv('data3.csv', index=False)

# %%
CSV4.to_csv('data4.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_948\1305811893.py in <module>
# ----> 1 CSV4.to_csv('data4.csv', index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...

# %%
CSV1=pd.read_csv('..\code\data1.csv')
CSV1
# Out:
#       Id  PetalLengthCm  PetalWidthCm
# 0      1            1.4           0.2
# 1      2            1.4           0.2
# 2      3            1.3           0.2
# 3      4            1.5           0.2
# 4      5            1.4           0.2
# ..   ...            ...           ...
# 145  146            5.2           2.3
# 146  147            5.0           1.9
# 147  148            5.2           2.0
# 148  149            5.4           2.3
# 149  150            5.1           1.8
#
# [150 rows x 3 columns]

# %%
CSV2=pd.read_csv('..\code\data2.csv')
CSV2.head(15)
# Out:
#     SepalLengthCm    SepalWidthCm
# 0             5.1  Three dot Five
# 1             4.9             3.5
# 2             4.7          3.Five
# 3             4.6               3
# 4             5.0               3
# 5             5.4           Three
# 6             4.6      three.five
# 7             5.0      THREE five
# 8             4.4             3.$
# 9             4.9             3.1
# 10            5.4             3.7
# 11            4.8             3.4
# 12            4.8               3
# 13            4.3               3
# 14            5.8               4

# %%
CSV3=pd.read_csv('..\code\data3.csv')
CSV3
# Out:
#      Id          Species
# 0    51  Iris-versicolor
# 1    52  Iris-versicolor
# 2    53  Iris-versicolor
# 3    54  Iris-versicolor
# 4    55  Iris-versicolor
# ..  ...              ...
# 95  146   Iris-virginica
# 96  147   Iris-virginica
# 97  148   Iris-virginica
# 98  149   Iris-virginica
# 99  150   Iris-virginica
#
# [100 rows x 2 columns]

# %%
CSV4=pd.read_csv('..\code\data4.csv')
CSV4.head(20)
# Out:
#     Id  PetalLengthCm  PetalWidthCm      Species
# 0    1            1.4           0.2  iris-setosa
# 1    2            1.4           0.2  IRIS-SETOSA
# 2    3            1.3           0.2   IRISsetosa
# 3    4            1.5           0.2  IRIS_SETOSA
# 4    5            1.4           0.2   irisSetosa
# 5    6            1.7           0.4   IrisSetosa
# 6    7            1.4           0.3  iris_setosa
# 7    8            1.5           0.2  iri$_$eto$a
# 8    9            1.4           0.2   irisSETOSA
# 9   10            1.5           0.1          NaN
# 10  11            1.5           0.2  Iris_setesa
# 11  12            1.6           0.2       setosa
# 12  13            1.4           0.1       Setosa
# 13  14            1.1           0.1       SETOSA
# 14  15            1.2           0.2       $e+osA
# 15  16            1.5           0.4  Iris-setosa
# 16  17            1.3           0.4  Iris-setosa
# 17  18            1.4           0.3  Iris-setosa
# ...

# %%
CSV4.isnull().sum()
# Out:
# Id               0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          1
# dtype: int64

# %% [markdown]
# # Connect to the MySQL using Python and create a Database

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', user='root',  
                        password='root')#give ur username, password
    if conn.is_connected():
        cursor = conn.cursor()
        # tips
        cursor.execute("CREATE DATABASE iris")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Error while connecting to MySQL 1007 (HY000): Can't create database 'iris'; database exists

# %% [markdown]
# # Create a table and Import the CSV data into the MySQL table

# %% [markdown]
# # Query the Table

# %% [markdown]
# # CSV1

# %%
CSV1
# Out:
#       Id  PetalLengthCm  PetalWidthCm
# 0      1            1.4           0.2
# 1      2            1.4           0.2
# 2      3            1.3           0.2
# 3      4            1.5           0.2
# 4      5            1.4           0.2
# ..   ...            ...           ...
# 145  146            5.2           2.3
# 146  147            5.0           1.9
# 147  148            5.2           2.0
# 148  149            5.4           2.3
# 149  150            5.1           1.8
#
# [150 rows x 3 columns]

# %% [markdown]
# # Create a table and Import the CSV data into the MySQL table

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='iris', user='root', password='root') # tips
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS data;') # tips_data
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
#tips_data(columnname1 datatype,columnname2 datatype .....)
        cursor.execute("CREATE TABLE d1(Id INT, PetalLengthCm FLOAT, PetalWidthCm FLOAT)")
        print("Table is created....")
        #loop through the data frame
        for i,row in CSV1.iterrows():
            #here %S means string values 
            # tips.tips_data
            sql = "INSERT INTO iris.d1 VALUES (%s,%s,%s)" # how many columns are there that many %s
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('iris',)
# Creating table....
# Error while connecting to MySQL 1050 (42S01): Table 'd1' already exists

# %% [markdown]
# # Query the Table

# %%
# Execute query
sql = "SELECT * FROM iris.d1" # tips.tips_data
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (1, 1.4, 0.2)
# (2, 1.4, 0.2)
# (3, 1.3, 0.2)
# (4, 1.5, 0.2)
# (5, 1.4, 0.2)
# (6, 1.7, 0.4)
# (7, 1.4, 0.3)
# (8, 1.5, 0.2)
# (9, 1.4, 0.2)
# (10, 1.5, 0.1)
# (11, 1.5, 0.2)
# (12, 1.6, 0.2)
# (13, 1.4, 0.1)
# (14, 1.1, 0.1)
# (15, 1.2, 0.2)
# (16, 1.5, 0.4)
# (17, 1.3, 0.4)
# (18, 1.4, 0.3)
# (19, 1.7, 0.3)
# (20, 1.5, 0.3)
# (21, 1.7, 0.2)
# (22, 1.5, 0.4)
# (23, 1.0, 0.2)
# (24, 1.7, 0.5)
# (25, 1.9, 0.2)
# (26, 1.6, 0.2)
# (27, 1.6, 0.4)
# (28, 1.5, 0.2)
# (29, 1.4, 0.2)
# (30, 1.6, 0.2)
# (31, 1.6, 0.2)
# (32, 1.5, 0.4)
# (33, 1.5, 0.1)
# (34, 1.4, 0.2)
# (35, 1.5, 0.1)
# (36, 1.2, 0.2)
# (37, 1.3, 0.2)
# (38, 1.5, 0.1)
# (39, 1.3, 0.2)
# (40, 1.5, 0.2)
# (41, 1.3, 0.3)
# (42, 1.3, 0.3)
# (43, 1.3, 0.2)
# (44, 1.6, 0.6)
# (45, 1.9, 0.4)
# (46, 1.4, 0.3)
# (47, 1.6, 0.2)
# (48, 1.4, 0.2)
# (49, 1.5, 0.2)
# (50, 1.4, 0.2)
# (51, 4.7, 1.4)
# (52, 4.5, 1.5)
# (53, 4.9, 1.5)
# (54, 4.0, 1.3)
# (55, 4.6, 1.5)
# (56, 4.5, 1.3)
# (57, 4.7, 1.6)
# (58, 3.3, 1.0)
# (59, 4.6, 1.3)
# ...

# %% [markdown]
# # CSV2

# %%
CSV2
# Out:
#      SepalLengthCm    SepalWidthCm
# 0              5.1  Three dot Five
# 1              4.9             3.5
# 2              4.7          3.Five
# 3              4.6               3
# 4              5.0               3
# ..             ...             ...
# 145            6.7               3
# 146            6.3             2.5
# 147            6.5               3
# 148            6.2             3.4
# 149            5.9               3
#
# [150 rows x 2 columns]

# %% [markdown]
# # Create a table and Import the CSV data into the MySQL table

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='iris', user='root', password='root') # tips
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS d2;') # tips_data
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
#tips_data(columnname1 datatype,columnname2 datatype .....)
        cursor.execute("CREATE TABLE d2(SepalLengthCm FLOAT, SepalWidthCm varchar(200))")
        print("Table is created....")
        #loop through the data frame
        for i,row in CSV2.iterrows():
            #here %S means string values 
            # tips.tips_data
            sql = "INSERT INTO iris.d2 VALUES (%s,%s)" # how many columns are there that many %s
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('iris',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %% [markdown]
# # Query the Table

# %%
# Execute query
sql = "SELECT * FROM iris.d2" # tips.tips_data
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (5.1, 'Three dot Five')
# (4.9, '3.5')
# (4.7, '3.Five')
# (4.6, '3')
# (5.0, '3')
# (5.4, 'Three')
# (4.6, 'three.five')
# (5.0, 'THREE five')
# (4.4, '3.$')
# (4.9, '3.1')
# (5.4, '3.7')
# (4.8, '3.4')
# (4.8, '3')
# (4.3, '3')
# (5.8, '4')
# (5.7, '4.4')
# (5.4, '3.9')
# (5.1, '3.5')
# (5.7, '3.8')
# (5.1, '3.8')
# (5.4, '3.4')
# (5.1, '3.7')
# (4.6, '3.6')
# (5.1, '3.3')
# (4.8, '3.4')
# (5.0, '3')
# (5.0, '3.4')
# (5.2, '3.5')
# (5.2, '3.4')
# (4.7, '3.2')
# (4.8, '3.1')
# (5.4, '3.4')
# (5.2, '4.1')
# (5.5, '4.2')
# (4.9, '3.1')
# (5.0, '3.2')
# (5.5, '3.5')
# (4.9, '3.1')
# (4.4, '3')
# (5.1, '3.4')
# (5.0, '3.5')
# (4.5, '2.3')
# (4.4, '3.2')
# (5.0, '3.5')
# (5.1, '3.8')
# (4.8, '3')
# (5.1, '3.8')
# (4.6, '3.2')
# (5.3, '3.7')
# (5.0, '3.3')
# (7.0, '3.2')
# (6.4, '3.2')
# (6.9, '3.1')
# (5.5, '2.3')
# (6.5, '2.8')
# (5.7, '2.8')
# (6.3, '3.3')
# (4.9, '2.4')
# (6.6, '2.9')
# (5.2, '2.7')
# (5.0, '2')
# (5.9, '3')
# (6.0, '2.2')
# (6.1, '2.9')
# (5.6, '2.9')
# (6.7, '3.1')
# ...

# %% [markdown]
# # CSV3

# %%
CSV3
# Out:
#      Id          Species
# 0    51  Iris-versicolor
# 1    52  Iris-versicolor
# 2    53  Iris-versicolor
# 3    54  Iris-versicolor
# 4    55  Iris-versicolor
# ..  ...              ...
# 95  146   Iris-virginica
# 96  147   Iris-virginica
# 97  148   Iris-virginica
# 98  149   Iris-virginica
# 99  150   Iris-virginica
#
# [100 rows x 2 columns]

# %% [markdown]
# # Create a table and Import the CSV data into the MySQL table

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='iris', user='root', password='root') # tips
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS d3;') # tips_data
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
#tips_data(columnname1 datatype,columnname2 datatype .....)
        cursor.execute("CREATE TABLE d3(Id INT, Species varchar(200))")
        print("Table is created....")
        #loop through the data frame
        for i,row in CSV3.iterrows():
            #here %S means string values 
            # tips.tips_data
            sql = "INSERT INTO iris.d3 VALUES (%s,%s)" # how many columns are there that many %s
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('iris',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %% [markdown]
# # Query the Table

# %%
# Execute query
sql = "SELECT * FROM iris.d3" # tips.tips_data
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (51, 'Iris-versicolor')
# (52, 'Iris-versicolor')
# (53, 'Iris-versicolor')
# (54, 'Iris-versicolor')
# (55, 'Iris-versicolor')
# (56, 'Iris-versicolor')
# (57, 'Iris-versicolor')
# (58, 'Iris-versicolor')
# (59, 'Iris-versicolor')
# (60, 'Iris-versicolor')
# (61, 'Iris-versicolor')
# (62, 'Iris-versicolor')
# (63, 'Iris-versicolor')
# (64, 'Iris-versicolor')
# (65, 'Iris-versicolor')
# (66, 'Iris-versicolor')
# (67, 'Iris-versicolor')
# (68, 'Iris-versicolor')
# (69, 'Iris-versicolor')
# (70, 'Iris-versicolor')
# (71, 'Iris-versicolor')
# (72, 'Iris-versicolor')
# (73, 'Iris-versicolor')
# (74, 'Iris-versicolor')
# (75, 'Iris-versicolor')
# (76, 'Iris-versicolor')
# (77, 'Iris-versicolor')
# (78, 'Iris-versicolor')
# (79, 'Iris-versicolor')
# (80, 'Iris-versicolor')
# (81, 'Iris-versicolor')
# (82, 'Iris-versicolor')
# (83, 'Iris-versicolor')
# (84, 'Iris-versicolor')
# (85, 'Iris-versicolor')
# (86, 'Iris-versicolor')
# (87, 'Iris-versicolor')
# (88, 'Iris-versicolor')
# ...

# %% [markdown]
# # CSV4

# %%
CSV4
# Out:
#     Id  PetalLengthCm  PetalWidthCm      Species
# 0    1            1.4           0.2  iris-setosa
# 1    2            1.4           0.2  IRIS-SETOSA
# 2    3            1.3           0.2   IRISsetosa
# 3    4            1.5           0.2  IRIS_SETOSA
# 4    5            1.4           0.2   irisSetosa
# 5    6            1.7           0.4   IrisSetosa
# 6    7            1.4           0.3  iris_setosa
# 7    8            1.5           0.2  iri$_$eto$a
# 8    9            1.4           0.2   irisSETOSA
# 9   10            1.5           0.1          NaN
# 10  11            1.5           0.2  Iris_setesa
# 11  12            1.6           0.2       setosa
# 12  13            1.4           0.1       Setosa
# 13  14            1.1           0.1       SETOSA
# 14  15            1.2           0.2       $e+osA
# 15  16            1.5           0.4  Iris-setosa
# 16  17            1.3           0.4  Iris-setosa
# 17  18            1.4           0.3  Iris-setosa
# ...

# %% [markdown]
# #  Create a table and Import the CSV data into the MySQL table

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='localhost', database='iris', user='root', password='root') # tips
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS d4;') # tips_data
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
#tips_data(columnname1 datatype,columnname2 datatype .....)
        cursor.execute("CREATE TABLE d4(Id INT,PetalLengthCm FLOAT, PetalWidthCm FLOAT, Species varchar(200))")
        print("Table is created....")
        #loop through the data frame
        for i,row in CSV4.iterrows():
            #here %S means string values 
            # tips.tips_data
            sql = "INSERT INTO iris.d4 VALUES (%s,%s,%s,%s)" # how many columns are there that many %s
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('iris',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted

# %% [markdown]
# # Query the Table

# %%
# Execute query
sql = "SELECT * FROM iris.d4" # tips.tips_data
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (1, 1.4, 0.2, 'iris-setosa')
# (2, 1.4, 0.2, 'IRIS-SETOSA')
# (3, 1.3, 0.2, 'IRISsetosa')
# (4, 1.5, 0.2, 'IRIS_SETOSA')
# (5, 1.4, 0.2, 'irisSetosa')
# (6, 1.7, 0.4, 'IrisSetosa')
# (7, 1.4, 0.3, 'iris_setosa')
# (8, 1.5, 0.2, 'iri$_$eto$a')
# (9, 1.4, 0.2, 'irisSETOSA')
# (10, 1.5, 0.1, None)
# (11, 1.5, 0.2, 'Iris_setesa')
# (12, 1.6, 0.2, 'setosa')
# (13, 1.4, 0.1, 'Setosa')
# (14, 1.1, 0.1, 'SETOSA')
# (15, 1.2, 0.2, '$e+osA')
# (16, 1.5, 0.4, 'Iris-setosa')
# (17, 1.3, 0.4, 'Iris-setosa')
# (18, 1.4, 0.3, 'Iris-setosa')
# (19, 1.7, 0.3, 'Iris-setosa')
# (20, 1.5, 0.3, 'Iris-setosa')
# (21, 1.7, 0.2, 'Iris-setosa')
# (22, 1.5, 0.4, 'Iris-setosa')
# (23, 1.0, 0.2, 'Iris-setosa')
# (24, 1.7, 0.5, 'Iris-setosa')
# (25, 1.9, 0.2, 'Iris-setosa')
# (26, 1.6, 0.2, 'Iris-setosa')
# (27, 1.6, 0.4, 'Iris-setosa')
# (28, 1.5, 0.2, 'Iris-setosa')
# (29, 1.4, 0.2, 'Iris-setosa')
# (30, 1.6, 0.2, 'Iris-setosa')
# (31, 1.6, 0.2, 'Iris-setosa')
# (32, 1.5, 0.4, 'Iris-setosa')
# ...
